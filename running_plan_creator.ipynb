# %% [markdown]
# # Running Plan Creator
#
# Um software completo para criar planos de treino de corrida personalizados.
#
# ## Características
#
# - **Múltiplas Distâncias**: 5K, 10K, Meia Maratona, Maratona
# - **Três Níveis**: Iniciante, Intermediário, Avançado
# - **Flexível**: 3 a 6 dias de treino por semana
# - **Progressivo**: Fases de construção, manutenção e taper
# - **Variado**: Treinos fáceis, tempo run, intervalados, fartlek, longões
#
# ---

# %% [markdown]
# ## 1. Importar os Módulos
#
# Primeiro, vamos importar as classes necessárias do nosso software.

# %%
from running_plan import RunningPlan, Week, Workout
from plan_generator import PlanGenerator
from datetime import datetime, timedelta

print("✓ Módulos importados com sucesso!")

# %% [markdown]
# ## 2. Criar um Plano Simples
#
# Vamos criar nosso primeiro plano de treino para uma corrida de 5K.

# %%
# Criar um plano de 5K para iniciantes
plano_5k = PlanGenerator.generate_plan(
    name="Meu Primeiro 5K",
    goal="5K",
    level="beginner",
    weeks=8,
    days_per_week=3
)

# Definir data de início
plano_5k.set_start_date(datetime(2025, 1, 6))  # Segunda-feira

print(f"Plano criado: {plano_5k.name}")
print(f"Meta: {plano_5k.goal}")
print(f"Nível: {plano_5k.level.capitalize()}")
print(f"Duração: {plano_5k.weeks} semanas")
print(f"Data de início: {plano_5k.start_date.strftime('%d/%m/%Y')}")
print(f"Data da prova: {plano_5k.get_race_date().strftime('%d/%m/%Y')}")

# %% [markdown]
# ## 3. Visualizar o Plano Completo
#
# Agora vamos visualizar todo o plano de treino.

# %%
print(plano_5k)

# %% [markdown]
# ## 4. Visualizar Uma Semana Específica
#
# Vamos examinar a semana 4 em detalhes.

# %%
semana_4 = plano_5k.get_week(4)
if semana_4:
    print(semana_4)
else:
    print("Semana não encontrada")

# %% [markdown]
# ## 5. Criar Plano de 10K Intermediário
#
# Vamos criar um plano mais desafiador para 10K.

# %%
plano_10k = PlanGenerator.generate_plan(
    name="Treino 10K Intermediário",
    goal="10K",
    level="intermediate",
    weeks=10,
    days_per_week=4
)

plano_10k.set_start_date(datetime(2025, 2, 3))

print(f"\n{'='*60}")
print(f"Plano: {plano_10k.name}")
print(f"Meta: {plano_10k.goal}")
print(f"Nível: {plano_10k.level.capitalize()}")
print(f"Duração: {plano_10k.weeks} semanas")
print(f"Dias de treino: {plano_10k.days_per_week} dias/semana")
print(f"{'='*60}")

# %% [markdown]
# ## 6. Análise de Quilometragem por Semana
#
# Vamos analisar como a quilometragem progride ao longo das semanas.

# %%
print(f"\nProgressão de Quilometragem - {plano_10k.name}")
print("=" * 50)

for week in plano_10k.schedule:
    week.calculate_total_distance()
    bar_length = int(week.total_distance_km / 2)  # Escala visual
    bar = "█" * bar_length
    print(f"Semana {week.week_number:2d}: {bar} {week.total_distance_km:.1f} km")

# Estatísticas
total_km = sum(w.total_distance_km for w in plano_10k.schedule)
media_km = total_km / len(plano_10k.schedule)
max_km = max(w.total_distance_km for w in plano_10k.schedule)

print("\nEstatísticas:")
print(f"Total: {total_km:.1f} km")
print(f"Média: {media_km:.1f} km/semana")
print(f"Pico: {max_km:.1f} km")

# %% [markdown]
# ## 7. Criar Plano de Meia Maratona Avançado
#
# Para corredores experientes, vamos criar um plano de Meia Maratona.

# %%
plano_meia = PlanGenerator.generate_plan(
    name="Meia Maratona - Nível Avançado",
    goal="Half Marathon",
    level="advanced",
    weeks=12,
    days_per_week=5
)

plano_meia.set_start_date(datetime(2025, 3, 3))

# Mostrar resumo das primeiras 4 semanas
print("\nPrimeiras 4 Semanas do Plano de Meia Maratona")
print("=" * 60)

for i in range(1, 5):
    week = plano_meia.get_week(i)
    if week:
        print(f"\nSemana {week.week_number}: {week.total_distance_km:.1f} km")
        if week.notes:
            print(f"  📝 {week.notes}")
        
        # Contar tipos de treino
        treinos = {}
        for workout in week.workouts:
            if workout.type != "Rest":
                treinos[workout.type] = treinos.get(workout.type, 0) + 1
        
        print(f"  Treinos: {', '.join([f'{v}x {k}' for k, v in treinos.items()])}")

# %% [markdown]
# ## 8. Criar Plano de Maratona
#
# O desafio máximo: um plano completo de maratona!

# %%
plano_maratona = PlanGenerator.generate_plan(
    name="Minha Primeira Maratona",
    goal="Marathon",
    level="intermediate",
    weeks=16,
    days_per_week=5
)

plano_maratona.set_start_date(datetime(2025, 1, 6))

print(f"\n{'='*60}")
print(f"PLANO DE MARATONA")
print(f"{'='*60}")
print(f"Nome: {plano_maratona.name}")
print(f"Início: {plano_maratona.start_date.strftime('%d/%m/%Y')}")
print(f"Prova: {plano_maratona.get_race_date().strftime('%d/%m/%Y')}")
print(f"Duração: {plano_maratona.weeks} semanas")
print(f"\nKM por fase:")

# Dividir em fases
fase_construcao = plano_maratona.schedule[:11]  # 70% de 16 = 11 semanas
fase_manutencao = plano_maratona.schedule[11:14]
fase_taper = plano_maratona.schedule[14:]

km_construcao = sum(w.total_distance_km for w in fase_construcao)
km_manutencao = sum(w.total_distance_km for w in fase_manutencao)
km_taper = sum(w.total_distance_km for w in fase_taper)

print(f"  📈 Construção (semanas 1-11): {km_construcao:.1f} km")
print(f"  💪 Manutenção (semanas 12-14): {km_manutencao:.1f} km")
print(f"  📉 Taper (semanas 15-16): {km_taper:.1f} km")
print(f"  🎯 TOTAL: {km_construcao + km_manutencao + km_taper:.1f} km")

# %% [markdown]
# ## 9. Análise de Tipos de Treino
#
# Vamos analisar a distribuição de tipos de treino no plano de maratona.

# %%
# Contar todos os tipos de treino
tipos_treino = {}

for week in plano_maratona.schedule:
    for workout in week.workouts:
        tipo = workout.type
        if tipo not in tipos_treino:
            tipos_treino[tipo] = {'count': 0, 'total_km': 0.0}
        
        tipos_treino[tipo]['count'] += 1
        if workout.distance_km:
            tipos_treino[tipo]['total_km'] += workout.distance_km

print("\nDistribuição de Tipos de Treino - Plano de Maratona")
print("=" * 60)

for tipo, dados in sorted(tipos_treino.items(), key=lambda x: x[1]['total_km'], reverse=True):
    count = dados['count']
    total_km = dados['total_km']
    if total_km > 0:
        media_km = total_km / count
        print(f"{tipo:20s}: {count:3d}x | {total_km:6.1f} km | Média: {media_km:.1f} km")
    else:
        print(f"{tipo:20s}: {count:3d}x | (descanso)")

# %% [markdown]
# ## 10. Salvar e Carregar Planos
#
# Vamos salvar nosso plano de maratona e depois carregá-lo novamente.

# %%
# Salvar plano
filename = "meu_plano_maratona.json"
plano_maratona.save_to_file(filename)
print(f"✓ Plano salvo em: {filename}")

# Carregar plano
plano_carregado = RunningPlan.load_from_file(filename)
print(f"✓ Plano carregado de: {filename}")
print(f"\nVerificação:")
print(f"  Nome: {plano_carregado.name}")
print(f"  Meta: {plano_carregado.goal}")
print(f"  Semanas: {len(plano_carregado.schedule)}")
print(f"  Data início: {plano_carregado.start_date.strftime('%d/%m/%Y')}")

# %% [markdown]
# ## 11. Comparação de Planos por Nível
#
# Vamos comparar planos de 10K para diferentes níveis de experiência.

# %%
print("\nComparação: Planos de 10K por Nível")
print("=" * 70)

niveis = ['beginner', 'intermediate', 'advanced']
planos_comparacao = {}

for nivel in niveis:
    plano = PlanGenerator.generate_plan(
        name=f"10K {nivel.capitalize()}",
        goal="10K",
        level=nivel,
        weeks=10,
        days_per_week=4
    )
    planos_comparacao[nivel] = plano
    
    # Calcular totais
    km_total = sum(w.total_distance_km for w in plano.schedule)
    km_medio = km_total / len(plano.schedule)
    km_pico = max(w.total_distance_km for w in plano.schedule)
    
    print(f"\n{nivel.upper():15s}:")
    print(f"  Total:   {km_total:6.1f} km")
    print(f"  Média:   {km_medio:6.1f} km/semana")
    print(f"  Pico:    {km_pico:6.1f} km")

print("\n" + "=" * 70)

# %% [markdown]
# ## 12. Visualização de Semana Completa
#
# Vamos ver como fica uma semana completa de treino com 6 dias.

# %%
plano_6dias = PlanGenerator.generate_plan(
    name="Treino Intensivo",
    goal="Half Marathon",
    level="advanced",
    weeks=12,
    days_per_week=6
)

print("\nSemana de Treino Intensivo (6 dias)")
print("=" * 70)

semana_exemplo = plano_6dias.get_week(6)  # Semana do meio
if semana_exemplo:
    for workout in semana_exemplo.workouts:
        emoji = {
            "Easy Run": "🏃",
            "Tempo Run": "⚡",
            "Interval Training": "💨",
            "Fartlek": "🎯",
            "Long Run": "🏃‍♂️💪",
            "Rest": "😴"
        }.get(workout.type, "🏃")
        
        if workout.distance_km:
            print(f"{emoji} {workout.day:10s}: {workout.type:20s} - {workout.distance_km:5.1f} km")
            if workout.description:
                print(f"   └─ {workout.description}")
        else:
            print(f"{emoji} {workout.day:10s}: {workout.type}")
    
    print(f"\n📊 Total da semana: {semana_exemplo.total_distance_km:.1f} km")

# %% [markdown]
# ## 13. Criar Seu Próprio Plano Personalizado
#
# Agora é sua vez! Modifique os parâmetros abaixo para criar seu plano personalizado.

# %%
# PERSONALIZE AQUI:
MEU_NOME = "Meu Plano Personalizado"
MINHA_META = "10K"  # Opções: "5K", "10K", "Half Marathon", "Marathon"
MEU_NIVEL = "intermediate"  # Opções: "beginner", "intermediate", "advanced"
MINHAS_SEMANAS = 10  # Entre 4 e 26
MEUS_DIAS = 4  # Entre 3 e 6

# Criar o plano
meu_plano = PlanGenerator.generate_plan(
    name=MEU_NOME,
    goal=MINHA_META,
    level=MEU_NIVEL,
    weeks=MINHAS_SEMANAS,
    days_per_week=MEUS_DIAS
)

# Definir data de início (próxima segunda-feira)
hoje = datetime.now()
dias_ate_segunda = (7 - hoje.weekday()) % 7
if dias_ate_segunda == 0:
    dias_ate_segunda = 7
proxima_segunda = hoje + timedelta(days=dias_ate_segunda)
meu_plano.set_start_date(proxima_segunda)

# Mostrar resumo
print("\n" + "="*70)
print("🎯 SEU PLANO PERSONALIZADO")
print("="*70)
print(f"Nome: {meu_plano.name}")
print(f"Meta: {meu_plano.goal}")
print(f"Nível: {meu_plano.level.capitalize()}")
print(f"Duração: {meu_plano.weeks} semanas")
print(f"Dias de treino: {meu_plano.days_per_week} dias/semana")
print(f"Início: {meu_plano.start_date.strftime('%d/%m/%Y (%A)')}")
print(f"Prova: {meu_plano.get_race_date().strftime('%d/%m/%Y (%A)')}")

# Estatísticas
km_total = sum(w.total_distance_km for w in meu_plano.schedule)
print(f"\nKilometragem total: {km_total:.1f} km")
print(f"Média semanal: {km_total/meu_plano.weeks:.1f} km")
print("="*70)

# %% [markdown]
# ## 14. Visualizar Seu Plano Completo
#
# Execute a célula abaixo para ver todas as semanas do seu plano personalizado.

# %%
print(meu_plano)

# %% [markdown]
# ## 15. Salvar Seu Plano
#
# Salve seu plano personalizado para uso futuro.

# %%
# Salvar o plano
nome_arquivo = f"{MEU_NOME.lower().replace(' ', '_')}.json"
meu_plano.save_to_file(nome_arquivo)

print(f"✓ Seu plano foi salvo em: {nome_arquivo}")
print(f"\nVocê pode carregar este plano mais tarde usando:")
print(f"  plano = RunningPlan.load_from_file('{nome_arquivo}')")
print(f"\nOu via linha de comando:")
print(f"  python cli.py view {nome_arquivo}")

# %% [markdown]
# ## 16. Dicas para o Sucesso
#
# ### 🎯 Princípios Fundamentais
#
# 1. **Consistência é a chave**: É melhor treinar regularmente do que fazer treinos intensos esporadicamente
# 2. **Escute seu corpo**: Descanse se sentir dor ou fadiga excessiva
# 3. **Aumente gradualmente**: Nunca aumente mais que 10% do volume semanal
# 4. **Recuperação é treino**: Os dias de descanso são quando seu corpo fica mais forte
# 5. **Nutrição importa**: Hidrate-se bem e coma adequadamente
# 6. **Confie no plano**: Especialmente durante o taper - resista à tentação de fazer mais
#
# ### 🏃 Tipos de Treino Explicados
#
# - **Easy Run**: Ritmo confortável, consegue conversar normalmente
# - **Tempo Run**: Ritmo "confortavelmente difícil", pode dizer frases curtas
# - **Intervals**: Repetições rápidas com recuperação entre elas
# - **Fartlek**: Brincadeira com ritmo, alterna velocidades livremente
# - **Long Run**: Corrida longa em ritmo fácil para construir resistência
#
# ### ⚠️ Prevenção de Lesões
#
# - Faça aquecimento antes de treinos intensos
# - Alongue após os treinos
# - Use tênis adequados e troque regularmente
# - Considere treinamento cruzado (natação, ciclismo)
# - Fortaleça o core e membros inferiores
#
# ### 📱 Recursos Adicionais
#
# - Use um relógio GPS para monitorar seus treinos
# - Junte-se a grupos de corrida locais
# - Considere contratar um treinador para orientação personalizada
# - Consulte um médico antes de iniciar qualquer programa de treino
#
# ---
#
# ### 🎉 Boa Sorte!
#
# Lembre-se: o objetivo não é apenas chegar à linha de chegada, mas aproveitar a jornada até lá. Bons treinos! 🏃‍♂️💪

# %% [markdown]
# ## 17. Experimente Mais!
#
# Use as células abaixo para experimentar e criar mais planos.

# %%
# Área livre para experimentação
# Crie seus próprios planos aqui!
